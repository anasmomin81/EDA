# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
type=dict(visa_df.dtypes)
cat_column=[key for key,value in type.items() if value=='object']
num_column=[key for key,value in type.items() if value!='object']

# %%
cat_column=visa_df.select_dtypes(include='object').columns
num_column=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Encoding**
#
# - Encoding means convert categorical columns data to Numerical data
#
# - Because ML models expect the data should be in numerical format
#
# - ML models developed by math algorithms
#
# - It is very very important to apply encoding
#
# - The following methods are:
#
#     - map
#
#     - np.where
#
#     - one hot encoding
#
#     - Lable Encoder

# %% [markdown]
# **Map**
#
# - Map is one method to convert categorical values to numerical
#
# - Take one categorical column
#
# - Get the unique lables first
#
# - make a dictionary with assign a number to each lable
#
# - For exapmle case_status has two lables
#
#     - Certified
#
#     - Denied
#
# - Assign 0 to certified, 1 to Denied
#
# - Create a dictionary lables as keys, number as values only
#
# - {'Certified':0,'Denied':1}

# %%
# Step-1: read the column
# Step-2: Get the unique lables
# Step-3: Make a dictionary 
# Step-4: Apply the map

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status_new']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case_status_new
# 0          Denied                1
# 1       Certified                0
# 2          Denied                1
# 3          Denied                1
# 4       Certified                0
# ...           ...              ...
# 25475   Certified                0
# 25476   Certified                0
# 25477   Certified                0
# 25478   Certified                0
# 25479   Certified                0
#
# [25480 rows x 13 columns]

# %%
# ATS automatic tracking system

# %%
# I want to appy the map methos for all categorical column
# Step-1: We need to get unique lables
# Step-2: we need to get a number = len unique lables
# Step-3: we need to create a dictionary

# %%
unique_lables=visa_df['case_status'].unique()
list1=[i for i in range(len(unique_lables))]
unique_lables,list1
# Out:
# (array(['Denied', 'Certified'], dtype=object), [0, 1])

# %%
unique_lables=sorted(visa_df['case_status'].unique())
list1=[i for i in range(len(unique_lables))]
dict1=dict(zip(unique_lables,list1))
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
# No need to create a new column rather than updating the existing one.
visa_df=pd.read_csv('Visadataset.csv')
unique_lables=sorted(visa_df['case_status'].unique())
list1=[i for i in range(len(unique_lables))]
dict1=dict(zip(unique_lables,list1))
visa_df['case_status']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#        case_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 25475            0
# 25476            0
# 25477            0
# 25478            0
# 25479            0
#
# [25480 rows x 12 columns]

# %%
visa_df=pd.read_csv('Visadataset.csv')
unique_lables=sorted(visa_df[i].unique())
cat_column=visa_df.select_dtypes(include='object').columns
for i in cat_column:
    list1=[i for i in range(len(unique_lables))]
    dict1=dict(zip(unique_lables,list1))
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0          NaN        NaN                    NaN                 NaN
# 1          NaN        NaN                    NaN                 NaN
# 2          NaN        NaN                    NaN                 NaN
# 3          NaN        NaN                    NaN                 NaN
# 4          NaN        NaN                    NaN                 NaN
# ...        ...        ...                    ...                 ...
# 25475      NaN        NaN                    NaN                 NaN
# 25476      NaN        NaN                    NaN                 NaN
# 25477      NaN        NaN                    NaN                 NaN
# 25478      NaN        NaN                    NaN                 NaN
# 25479      NaN        NaN                    NaN                 NaN
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                        NaN            14513         2007
# 1                        NaN             2412         2002
# 2                        NaN            44444         2008
# 3                        NaN               98         1897
# 4                        NaN             1082         2005
# ...                      ...              ...          ...
# 25475                    NaN             2601         2008
# 25476                    NaN             3274         2006
# 25477                    NaN             1121         1910
# 25478                    NaN             1918         1887
# 25479                    NaN             3195         1960
#
#        region_of_employment  prevailing_wage  unit_of_wage  \
# 0                       NaN         592.2029           NaN
# 1                       NaN       83425.6500           NaN
# 2                       NaN      122996.8600           NaN
# 3                       NaN       83434.0300           NaN
# 4                       NaN      149907.3900           NaN
# ...                     ...              ...           ...
# 25475                   NaN       77092.5700           NaN
# 25476                   NaN      279174.7900           NaN
# 25477                   NaN      146298.8500           NaN
# 25478                   NaN       86154.7700           NaN
# 25479                   NaN       70876.9100           NaN
#
#        full_time_position  case_status
# 0                     NaN            1
# 1                     NaN            0
# 2                     NaN            1
# 3                     NaN            1
# 4                     NaN            0
# ...                   ...          ...
# 25475                 NaN            0
# 25476                 NaN            0
# 25477                 NaN            0
# 25478                 NaN            0
# 25479                 NaN            0
#
# [25480 rows x 12 columns]

# %% [markdown]
# **LableEncoder**
#
# - LableEncoder is a method to convert categorical data to Numerical data
#
# - LableEncoder is a same way, how we did in the above
#
# - The for loop map method we explored
#
# - But the LableEmcoder also do the same
#
# - It is under **sickit-learn** we usually called as **sklearn**
#
# - Uder skleran we have class called as preprocessing
#
# - Because currently we are doing data preprocessing only
#
# - Under preprocessing class we have a method called as **LableEncoder**
#
# - sklearn
#
#     - Preprocessing
#
#     - LableEncoder
#
# - Any sklearn package has 3 steps
#
#     - Step-1: Read the package
#
#     - Step-2: Save the package
#
#     - Step-3: Apply fit transform on data

# %%
visa_df=pd.read_csv('Visadataset.csv')
# Step-1: Read the package
from sklearn.preprocessing import LabelEncoder
# Step-2: Save the package or call the method
le=LabelEncoder()
# Step-3: Apply fit transform on data
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#        case_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 25475            0
# 25476            0
# 25477            0
# 25478            0
# 25479            0
#
# [25480 rows x 12 columns]

# %%
visa_df=pd.read_csv('Visadataset.csv')
cat_column=visa_df.select_dtypes(include='object').columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_column:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# 1                          0             2412         2002
# 2                          1            44444         2008
# 3                          0               98         1897
# 4                          0             1082         2005
# ...                      ...              ...          ...
# 25475                      1             2601         2008
# 25476                      0             3274         2006
# 25477                      0             1121         1910
# 25478                      1             1918         1887
# 25479                      0             3195         1960
#
#        region_of_employment  prevailing_wage  unit_of_wage  \
# 0                         4         592.2029             0
# 1                         2       83425.6500             3
# 2                         4      122996.8600             3
# 3                         4       83434.0300             3
# 4                         3      149907.3900             3
# ...                     ...              ...           ...
# 25475                     3       77092.5700             3
# 25476                     2      279174.7900             3
# 25477                     3      146298.8500             3
# 25478                     4       86154.7700             3
# 25479                     1       70876.9100             3
#
#        full_time_position  case_status
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            1
# 4                       1            0
# ...                   ...          ...
# 25475                   1            0
# 25476                   1            0
# 25477                   0            0
# 25478                   1            0
# 25479                   1            0
#
# [25480 rows x 12 columns]

# %% [markdown]
# **fit and transform**
#
# - fit means develop the logic
#
# - transform means process the logic
#
# - If we observe in map method first we developed dictionary logic
#
# - The we apply that dictionary to column
#
# - Developing the dictionary is kind of fit
#
# - Apply the dictionary to column means we are tranforming the data cat to num
#
# - Whenever we are tranforming or changing the data then use **fit transform**
#
# - If we are not changing the data then only **fit**

# %% [markdown]
# **np.where**

# %% [markdown]
# - using np.where also we can change the categoricldata to Numerical
#
# - But np.where is only for binary condition
#
# - np.where is same as if-else
#
# - If conditoin is True : will apply True value
#
# - If conditoiin is False: will apply False value
#
# - So np.whee use for only binary lables
#
# - A column should have only two unique lables

# %%
# value=='certified  replace with 0
# otherwise 1
# np.where (con,0,1)

# %%
visa_df=pd.read_csv('Visadataset.csv')
con=visa_df['case_status']=='Certified'
visa_df['case status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  case status
# 0          Denied            1
# 1       Certified            0
# 2          Denied            1
# 3          Denied            1
# 4       Certified            0
# ...           ...          ...
# 25475   Certified            0
# 25476   Certified            0
# 25477   Certified            0
# 25478   Certified            0
# 25479   Certified            0
#
# [25480 rows x 13 columns]

# %% [markdown]
# **One hot endorder**
#
# - One hot means if one will be ON, another will be OFF
#
# - ON represents with 1
#
# - OFF represents with 0
#
# - For example case status has two unique lables
#
#     - Certified
#
#     - Denied
#
# - one hot encoder creates new columns which is equal to number of unique lables
#
# - For example case status will create two new extra columns
#
#     - case_status_Certified
#
#     - case_status_Denied
#
# |case_status|case_status_certified|case_status_Denied|
# |-|-|-|
# |Denied|0|1
# |Certified|1|0
# |Denied|0|1
